# %% [markdown]
# # Introduction to LangGraph Financial Agent
# This notebook walks you through state validation and graph invocations.

# %%
from src.agent.graph import build_financial_agent
graph = build_financial_agent()
print('Graph compiled successfully. Nodes:', list(graph.nodes.keys()))
